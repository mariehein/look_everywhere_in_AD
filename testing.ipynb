# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.rcParams['pgf.rcfonts'] = False
plt.rcParams['font.serif'] = []
plt.rcParams['text.usetex'] = True
#plt.rcParams['figure.figsize'] = 3.5, 2.625
plt.rcParams['axes.formatter.useoffset'] = False
plt.rcParams['lines.linewidth'] = 2
plt.rcParams['errorbar.capsize'] = 2
plt.rcParams['grid.linewidth'] = 0.5
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['axes.titlesize'] = 16
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12
plt.rcParams['legend.title_fontsize'] = 12
plt.rcParams['legend.fontsize'] = 12
#plt.rcParams['legend.frameon'] = False

# %%
folder = "/hpcwork/zu992399/look_elsewhere/NN_kfold_calibration/"
NN_k_N_samples_after = np.load(folder+"N_samples_after.npy")
NN_k_N_samples = np.load(folder+"N_samples.npy")
NN_k_N_after = np.load(folder+"N_after.npy")
NN_k_N = np.load(folder+"N.npy")

folder = "/hpcwork/zu992399/look_elsewhere/NN_calibration/"
NN_N_samples_after = np.load(folder+"N_samples_after.npy")
NN_N_samples = np.load(folder+"N_samples.npy")
NN_N_after = np.load(folder+"N_after.npy")
NN_N = np.load(folder+"N.npy")
NN_N_samples_after_fixed = np.load(folder+"N_samples_after_fixed.npy")
NN_N_after_fixed = np.load(folder+"N_after_fixed.npy")

folder = "/hpcwork/zu992399/look_elsewhere/BDT_calibration_kfold_niter2/"
BDT_fixed_N_samples_after = np.load(folder+"N_samples_after.npy")
BDT_fixed_N_samples = np.load(folder+"N_samples.npy")
BDT_fixed_N_after = np.load(folder+"N_after.npy")
BDT_fixed_N = np.load(folder+"N.npy")


folder = "/hpcwork/zu992399/look_elsewhere/BDT_calibration_bins255/"
BDT_N_samples_after = np.load(folder+"N_samples_after.npy")
BDT_N_samples = np.load(folder+"N_samples.npy")
BDT_N_after = np.load(folder+"N_after.npy")
BDT_N = np.load(folder+"N.npy")
BDT_N_samples_after_fixed = np.load(folder+"N_samples_after_fixed.npy")
BDT_N_after_fixed = np.load(folder+"N_after_fixed.npy")


folder = "/hpcwork/zu992399/look_elsewhere/BDT_calibration_change_dataBT/"
BDT_fixed2_N_samples_after = np.load(folder+"N_samples_after.npy")
BDT_fixed2_N_samples = np.load(folder+"N_samples.npy")
BDT_fixed2_N_after = np.load(folder+"N_after.npy")
BDT_fixed2_N = np.load(folder+"N.npy")
BDT_fixed2_N_samples_after_fixed = np.load(folder+"N_samples_after_fixed.npy")
BDT_fixed2_N_after_fixed = np.load(folder+"N_after_fixed.npy")

folder = "/hpcwork/zu992399/look_elsewhere/NN_calibration_change_dataBT/"
NN_fixed2_N_samples_after = np.load(folder+"N_samples_after.npy")
NN_fixed2_N_samples = np.load(folder+"N_samples.npy")
NN_fixed2_N_after = np.load(folder+"N_after.npy")
NN_fixed2_N = np.load(folder+"N.npy")
NN_fixed2_N_samples_after_fixed = np.load(folder+"N_samples_after_fixed.npy")
NN_fixed2_N_after_fixed = np.load(folder+"N_after_fixed.npy")

# %%
fig, ax = plt.subplots(1,4, figsize=(15,6))
plt.figure()
for ind in range(4):
    ax[ind].hist((BDT_fixed_N_after[:,ind], BDT_fixed_N_samples_after[:, ind]), bins=75, color=("red", "black"), label=("Data", "BT"), density=True, histtype="step")
    ax[ind].axvline(np.mean(BDT_fixed_N_samples_after[:,ind]*BDT_fixed_N[:,ind]/BDT_fixed_N_samples[:,ind]), linestyle="dashed", color="black", label="BT")
    ax[ind].axvline(np.mean(BDT_fixed_N_after[:,ind]), linestyle="dashed", color="red", label="Mean data")
    ax[ind].legend()

    print(np.mean(BDT_fixed_N_samples_after[:,ind]*BDT_fixed_N[:,ind]/BDT_fixed_N_samples[:,ind]), np.mean(BDT_fixed_N_after[:,ind]))
# Out:
# 17967.3367 17966.9424
# 2041.5575 2041.0308
# 193.6398 192.685
# 10.371 8.3049

# %%
fig, ax = plt.subplots(1,3, figsize=(15,6))
plt.figure()
for ind in range(3):
    ax[ind].hist((BDT_fixed2_N_after[:,ind], BDT_fixed2_N_samples_after[:,ind]), bins=75, color=("red", "black"), label=("Data", "BT"), density=True, histtype="step")
    ax[ind].axvline(np.mean(BDT_fixed2_N_samples_after[:,ind]*BDT_fixed2_N[:,ind]/BDT_fixed2_N_samples[:,ind]), linestyle="dashed", color="black", label="BT")
    ax[ind].axvline(np.mean(BDT_fixed2_N_after[:,ind]), linestyle="dashed", color="red", label="Mean data")
    ax[ind].legend()
plt.show()

fig, ax = plt.subplots(1,3, figsize=(15,6))
plt.figure()
for ind in range(3):
    ax[ind].hist((BDT_fixed2_N_after_fixed[:,ind], BDT_fixed2_N_samples_after_fixed[:,ind]), bins=75, color=("red", "black"), label=("Data", "BT"), density=True, histtype="step")
    ax[ind].axvline(np.mean(BDT_fixed2_N_samples_after_fixed[:,ind]*BDT_fixed2_N[:,ind]/BDT_fixed2_N_samples[:,ind]), linestyle="dashed", color="black", label="BT")
    ax[ind].axvline(np.mean(BDT_fixed2_N_after_fixed[:,ind]), linestyle="dashed", color="red", label="Mean data")
    ax[ind].legend()
plt.show()

# %%
fig, ax = plt.subplots(1,3, figsize=(15,6))
plt.figure()
for ind in range(3):
    ax[ind].hist((BDT_N_after[:,ind], BDT_N_samples_after[:,ind]), bins=75, color=("red", "black"), label=("Data", "BT"), density=True, histtype="step")
    ax[ind].axvline(np.mean(BDT_N_samples_after[:,ind]*BDT_N[:,ind]/BDT_N_samples[:,ind]), linestyle="dashed", color="black", label="BT")
    ax[ind].axvline(np.mean(BDT_N_after[:,ind]), linestyle="dashed", color="red", label="Mean data")
    ax[ind].legend()
plt.show()

fig, ax = plt.subplots(1,3, figsize=(15,6))
plt.figure()
for ind in range(3):
    ax[ind].hist((BDT_N_after_fixed[:,ind], BDT_N_samples_after_fixed[:,ind]), bins=75, color=("red", "black"), label=("Data", "BT"), density=True, histtype="step")
    ax[ind].axvline(np.mean(BDT_N_samples_after_fixed[:,ind]*BDT_N[:,ind]/BDT_N_samples[:,ind]), linestyle="dashed", color="black", label="BT")
    ax[ind].axvline(np.mean(BDT_N_after_fixed[:,ind]), linestyle="dashed", color="red", label="Mean data")
    ax[ind].legend()
plt.show()

# %%
fig, ax = plt.subplots(1,3, figsize=(15,6))
plt.figure()
for ind in range(3):
    ax[ind].hist((NN_fixed2_N_after[:,ind], NN_fixed2_N_samples_after[:,ind]), bins=75, color=("red", "black"), label=("Data", "BT"), density=True, histtype="step")
    ax[ind].axvline(np.mean(NN_fixed2_N_samples_after[:,ind]*NN_fixed2_N[:,ind]/NN_fixed2_N_samples[:,ind]), linestyle="dashed", color="black", label="BT")
    ax[ind].axvline(np.mean(NN_fixed2_N_after[:,ind]), linestyle="dashed", color="red", label="Mean data")
    ax[ind].legend()
plt.show()

fig, ax = plt.subplots(1,3, figsize=(15,6))
plt.figure()
for ind in range(3):
    ax[ind].hist((NN_fixed2_N_after_fixed[:,ind], NN_fixed2_N_samples_after_fixed[:,ind]), bins=75, color=("red", "black"), label=("Data", "BT"), density=True, histtype="step")
    ax[ind].axvline(np.mean(NN_fixed2_N_samples_after_fixed[:,ind]*NN_fixed2_N[:,ind]/NN_fixed2_N_samples[:,ind]), linestyle="dashed", color="black", label="BT")
    ax[ind].axvline(np.mean(NN_fixed2_N_after_fixed[:,ind]), linestyle="dashed", color="red", label="Mean data")
    ax[ind].legend()
plt.show()

# %%
fig, ax = plt.subplots(1,3, figsize=(15,6))
plt.figure()
for ind in range(3):
    ax[ind].hist((BDT_fixed_N_after[:,ind]), bins=75, color=("red"), label=("Data"), density=True, histtype="step")
    ax[ind].axvline(BDT_fixed_N_samples_after[0,ind]*BDT_fixed_N[0,ind]/BDT_fixed_N_samples[0,ind], linestyle="dashed", color="black", label="BT")
    ax[ind].axvline(np.mean(BDT_fixed_N_after[:,ind]), linestyle="dashed", color="red", label="Mean data")
    ax[ind].legend()

# %%
fig, ax = plt.subplots(1,3, figsize=(15,6))
plt.figure()
for ind in range(3):
    ax[ind].hist((BDT_N_after[:,ind], BDT_N_samples_after[:,ind]*BDT_N[:,ind]/BDT_N_samples[:,ind]), bins=75, color=("red", "black"), label=("Data", "BT"), density=True, histtype="step")
    ax[ind].axvline(np.mean(BDT_N_samples_after[:,ind]*BDT_N[:,ind]/BDT_N_samples[:,ind]), linestyle="dashed", color="black", label="BT")
    ax[ind].axvline(np.mean(BDT_N_after[:,ind]), linestyle="dashed", color="red", label="Mean data")
    ax[ind].legend()

# %%
fig, ax = plt.subplots(1,3, figsize=(15,6))
plt.figure()
for ind in range(3):
    ax[ind].hist((NN_k_N_after[:,ind], NN_k_N_samples_after[:,ind]*NN_k_N[:,ind]/NN_k_N_samples[:,ind]), bins=75, color=("red", "black"), label=("Data", "BT"), density=True, histtype="step")
    ax[ind].axvline(np.mean(NN_k_N_samples_after[:,ind]*NN_k_N[:,ind]/NN_k_N_samples[:,ind]), linestyle="dashed", color="black", label="BT")
    ax[ind].axvline(np.mean(NN_k_N_after[:,ind]), linestyle="dashed", color="red", label="Mean data")
    ax[ind].legend()
    ax[ind].set_yscale("log")
    print(np.median(NN_k_N_samples_after[:,ind]*NN_k_N[:,ind]/NN_k_N_samples[:,ind]), np.median(NN_k_N_after[:,ind]))
    print(np.mean(NN_k_N_samples_after[:,ind]*NN_k_N[:,ind]/NN_k_N_samples[:,ind]), np.mean(NN_k_N_after[:,ind]))
# Out:
# 2505.0 2505.0
# 2501.937 2502.892
# 255.0 256.0
# 254.83 255.78
# 30.0 29.0
# 29.982 29.88

# %%
fig, ax = plt.subplots(1,3, figsize=(15,6))
plt.figure()
print(np.argwhere(NN_N_samples_after!=2794))
for ind in range(3):
    ax[ind].hist((NN_N_after[:,ind], NN_N_samples_after[:,ind]*NN_N[:,ind]/NN_N_samples[:,ind]), bins=75, color=("red", "black"), label=("Data", "BT"), density=True, histtype="step")
    ax[ind].axvline(np.mean(NN_N_samples_after[:,ind]*NN_N[:,ind]/NN_N_samples[:,ind]), linestyle="dashed", color="black", label="BT")
    ax[ind].axvline(np.mean(NN_N_after[:,ind]), linestyle="dashed", color="red", label="Mean data")
    ax[ind].legend()
    ax[ind].set_yscale("log")
    print(np.mean(NN_N_samples_after[:,ind]*NN_N[:,ind]/NN_N_samples[:,ind]), np.mean(NN_N_after[:,ind]))

fig, ax = plt.subplots(1,3, figsize=(15,6))
plt.figure()
print(np.argwhere(NN_N_samples_after!=2794))
for ind in range(3):
    ax[ind].hist((NN_N_after_fixed[:,ind], NN_N_samples_after_fixed[:,ind]*NN_N[:,ind]/NN_N_samples[:,ind]), bins=75, color=("red", "black"), label=("Data", "BT"), density=True, histtype="step")
    ax[ind].axvline(np.mean(NN_N_samples_after_fixed[:,ind]*NN_N[:,ind]/NN_N_samples[:,ind]), linestyle="dashed", color="black", label="BT")
    ax[ind].axvline(np.mean(NN_N_after_fixed[:,ind]), linestyle="dashed", color="red", label="Mean data")
    ax[ind].legend()
    ax[ind].set_yscale("log")
    print(np.mean(NN_N_samples_after_fixed[:,ind]*NN_N[:,ind]/NN_N_samples[:,ind]), np.mean(NN_N_after_fixed[:,ind]))
# Out:
# [[  0   0]
#  [  0   1]
#  [  0   2]
#  ...
#  [999   0]
#  [999   1]
#  [999   2]]
# 999.975 1003.101
# 99.995 101.291
# 10.0 10.871
# [[  0   0]
#  [  0   1]
#  [  0   2]
#  ...
#  [999   0]
#  [999   1]
#  [999   2]]
# 4292.436 4291.428
# 65.901 66.461
# 4.618 4.786

# %%
fig, ax = plt.subplots(1,3, figsize=(15,6))
plt.figure()
print(np.argwhere(NN_N_samples_after!=2794))
for ind in range(3):
    ax[ind].hist((NN_N_after_fixed[NN_N_samples_after[:,0]!=2794,ind], NN_N_samples_after_fixed[NN_N_samples_after[:,0]!=2794,ind]*NN_N[NN_N_samples_after[:,0]!=2794,ind]/NN_N_samples[NN_N_samples_after[:,0]!=2794,ind]), bins=75, color=("red", "black"), label=("Data", "BT"), density=True, histtype="step")
    ax[ind].axvline(np.mean(NN_N_samples_after_fixed[NN_N_samples_after[:,0]!=2794,ind]*NN_N[NN_N_samples_after[:,0]!=2794,ind]/NN_N_samples[NN_N_samples_after[:,0]!=2794,ind]), linestyle="dashed", color="black", label="BT")
    ax[ind].axvline(np.mean(NN_N_after_fixed[NN_N_samples_after[:,0]!=2794,ind]), linestyle="dashed", color="red", label="Mean data")
    ax[ind].legend()
    ax[ind].set_yscale("log")
# Out:
# [[   0    0]
#  [   0    1]
#  [   0    2]
#  ...
#  [9999    0]
#  [9999    1]
#  [9999    2]]

# %%
folder = "/hpcwork/zu992399/look_elsewhere/NN_kfold_calibration/"
run=1000
BT = np.load(folder+"run300/BT_preds.npy")
print(BT[0].shape)
data = np.load(folder+"run300/data_preds.npy")
plt.figure()
plt.hist((BT[0], data[0]), color=("black", "red"), label=("BT", "data"), histtype="step", bins=500)
plt.legend()
plt.yscale("log")
# Out:
# (50000,)
